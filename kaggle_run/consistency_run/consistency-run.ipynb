# %%
# !apt-get update -qq && apt-get install -y -qq zstd
# !curl -fsSL https://ollama.com/install.sh | sh
# !which ollama || echo 'NOT ON PATH'

# %%
import subprocess, time, urllib.request

subprocess.Popen(['ollama', 'serve'])
for _ in range(30):
    try:
        urllib.request.urlopen('http://localhost:11434/api/version', timeout=2)
        print('Ollama server is up')
        break
    except Exception:
        time.sleep(2)
else:
    raise RuntimeError('Ollama server did not come up in time')

# %%
# !git clone https://github.com/orceal-lab/cot-failure-modes.git
# %cd cot-failure-modes
# !pip install -q -r requirements.txt

# %%
# !ollama pull mistral:7b-instruct-q4_K_M

# %%
# !python run_experiment.py --problems problems/arithmetic_steps.json --repeats 3 --model "ollama:mistral:7b-instruct-q4_K_M"

# %%
# !python analyze.py results/raw_*_arithmetic_steps_x3_*.json --results-dir results/consistency
# !python consistency_report.py "results/consistency/analysis_*.csv" --results-dir results/consistency

# %%
import shutil
shutil.make_archive('/kaggle/working/results', 'zip', 'results')
print('Zipped results to /kaggle/working/results.zip')
